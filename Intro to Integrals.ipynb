# %%
from sympy import Function, Symbol, integrate, lambdify
from sympy.plotting import plot
import scipy as si
import numpy as np
import matplotlib.pyplot as plt
import mpmath

# %%
sy.init_printing(pretty_print=True)

# %%
x = sy.Symbol("x")

F = x**2

plot(F)

# %%
Fi = sy.integrate(F, x)
Fi
# Out:
#  3
# x
# ──
# 3

# %%
plot(Fi, F)

# %%
f  = lambdify(x, F, "mpmath")
# Out:
# 1

# %%
x = np.linspace(-10, 10, 100)
y = f(x)

# %%
plt.plot(x, y)
