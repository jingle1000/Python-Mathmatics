# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sympy as sy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
length = lambda x: 8-2*x
width = lambda x: 15-2*x
height = lambda x: x
v = lambda x: length(x)*width(x)*height(x)

# %%
v = sy.sympify(length)
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\sympify.py in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     367         a = a.replace('\n', '')
# --> 368         expr = parse_expr(a, local_dict=locals, transformations=transformations, evaluate=evaluate)
#     369     except (TokenError, SyntaxError) as exc:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\parsing\sympy_parser.py in parse_expr(s, local_dict, transformations, global_dict, evaluate)
#     964
# --> 965     return eval_expr(code, local_dict, global_dict)
#     966
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\parsing\sympy_parser.py in eval_expr(code, local_dict, global_dict)
#     877     expr = eval(
# --> 878         code, global_dict, local_dict)  # take local objects in preference
#     879
#
# ...

# %%
volume
# Out:
# 78
